# %% [markdown]
# <a href="https://colab.research.google.com/github/pyronet/2024-III_BCD2202_Introducci-n_tecnolog-a_Informatica_-Introducci-n_Programaci-n/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import csv


# URL del conjunto de datos2023
#url2023 = r'/content/sample_data/estadsticaspoliciales2023_modificado.xlsx'
# URL del conjunto de datos2023
#url2022 = r'/content/sample_data/estadsticaspoliciales2022_modificado.xlsx'

# URL del conjunto limpio de datos2023
url2023 = r'/content/sample_data/Guanacaste_2023_clean.xlsx'
# URL del conjunto limpio de datos2023
url2022 = r'/content/sample_data/Guanacaste_2022_clean.xlsx'

# %%
# Leer el conjunto de datos 2023
# Use pd.read_excel to read excel files instead of pd.read_csv
df2023 = pd.read_excel(url2023)
# Leer el conjunto de datos 2022
# Use pd.read_excel to read excel files instead of pd.read_csv
df2022 = pd.read_excel(url2022)


pd.set_option('display.max_rows', 100)
print(df2023)
print(df2022)
# Out:
#                                   Delito  \
# 0             DELITOS CONTRA LA LIBERTAD
# 1            DELITOS CONTRA LA PROPIEDAD
# 2            DELITOS CONTRA LA PROPIEDAD
# 3            DELITOS CONTRA LA PROPIEDAD
# 4            DELITOS CONTRA LA PROPIEDAD
# ...                                  ...
# 65721  DELITOS CONTRA LA SEGURIDAD COMUN
# 65722             DELITOS CONTRA LA VIDA
# 65723                      OTROS DELITOS
# 65724                      OTROS DELITOS
# 65725  OTROS DELITOS CONTRA LA PROPIEDAD
#
#                                          SubDelito      Fecha  \
# 0      DELITOS CONTRA LA LIBERTAD DE DETERMINACION 2023-08-31
# 1                                           ASALTO 2023-08-31
# 2                                           ASALTO 2023-08-31
# 3                                           ASALTO 2023-08-31
# 4                                            HURTO 2023-08-31
# ...                                            ...        ...
# ...

# %%
#df2023

#print(df2023[["Delito"]].groupby('Delito').size().sort_values(ascending=False))

#df2023[["Delito"]] = df2023[df2023['Delito']].str.upper()

#df2023 = df2023[df2023['Delito'].str.upper() ]


#Limpieza de la parte de delitos


df2023 = df2023[df2023['Delito'].str.isupper()]
#print(df2023[["Delito"]].groupby('Delito').size().sort_values(ascending=False))

df2023['Delito'] = df2023['Delito'].str.replace('OTROS DELITOSSSSSSSSSSSSSSSSSS', 'OTROS DELITOS')

df2023['Delito'] = df2023['Delito'].str.replace('ESTAFAS Y OTRAS DEFRAUDACIONESSWWW', 'ESTAFAS Y OTRAS DEFRAUDACIONES')

df2023['Delito'] = df2023['Delito'].str.replace('DELITOS CONTRA LA PROPIEDAAAAAAD', 'DELITOS CONTRA LA PROPIEDAD')


df2023['Delito'] = df2023['Delito'].str.replace('DLITOS INFORMATICOS', 'DELITOS INFORMATICOS')


df2023['Delito'] = df2023['Delito'].str.replace('DELITOSSSSS SEXUALES', 'DELITOS SEXUALES')


df2023['Delito'] = df2023['Delito'].str.replace('DELITOS CONTRA LA LIBERTADSSSSSSS', 'DELITOS CONTRA LA LIBERTAD')


df2023['Delito'] = df2023['Delito'].str.replace('NO DELITO NO DELITOOOOOOOOOOOOOOO', 'NO DELITO NO DELITO')


df2023['Delito'] = df2023['Delito'].str.replace('DELITOS CONTRA LA BUENA FE DELOS NEGOCIOS', 'DELITOS CONTRA LA BUENA FE DE LOS NEGOCIOS')


df2023['Delito'] = df2023['Delito'].str.replace('DELITOS CONTRA LA VIDA LA VIDA LA VIDA', 'DELITOS CONTRA LA VIDA')


df2023['Delito'] = df2023['Delito'].str.replace('NO DELITO NO DELITO', 'NO DELITO')

print(df2023[["Delito"]].groupby('Delito').size().sort_values(ascending=False))


df2023.dtypes


#Limpieza de la parte de delitos 2022


df2022 = df2022[df2022['Delito'].str.isupper()]
#print(df2023[["Delito"]].groupby('Delito').size().sort_values(ascending=False))

df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA PROPIEDADDDDDDD', 'DELITOS CONTRA LA PROPIEDAD')

df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA PROPIEDADDDDDDDDDDD', 'DELITOS CONTRA LA PROPIEDAD')

df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA VIDA VIDA VISA', 'DELITOS CONTRA LA VIDA')


df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA VIDAAAA', 'DELITOS CONTRA LA VIDA')


df2022['Delito'] = df2022['Delito'].str.replace('DELITS SEXUALES', 'DELITOS SEXUALES')


df2022['Delito'] = df2022['Delito'].str.replace('ESTAFAS Y OTRAS DEFRAUDACIONES YEI', 'ESTAFAS Y OTRAS DEFRAUDACIONES')


df2022['Delito'] = df2022['Delito'].str.replace('OTROS OTROS DELITOS', 'OTROS DELITOS')

df2022['Delito'] = df2022['Delito'].str.replace('DELITOS DELITOS  DELITOS CONTRA LA PROPIEDAD ', 'DELITOS CONTRA LA PROPIEDAD')

df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA PROPIEDADDDDD', 'DELITOS CONTRA LA PROPIEDAD')


df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA PROPIEDA', 'DELITOS CONTRA LA PROPIEDAD')


df2022['Delito'] = df2022['Delito'].str.replace('DELITOS DELITOS  DELITOS CONTRA LA PROPIEDADD', 'DELITOS CONTRA LA PROPIEDAD')

df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA LIBERTAD LIBERTAD', 'DELITOS CONTRA LA LIBERTAD')


df2022['Delito'] = df2022['Delito'].str.replace('DELITOS CONTRA LA PROPIEDADDD', 'DELITOS CONTRA LA PROPIEDAD')


df2022['Delito'] = df2022['Delito'].str.replace('OTROS DELITOS CONTRA LA PROPIEDADD', 'OTROS DELITOS CONTRA LA PROPIEDAD')




print(df2022[["Delito"]].groupby('Delito').size().sort_values(ascending=False))


df2022.dtypes
# Out:
# Delito
# DELITOS CONTRA LA PROPIEDAD                         29687
# ESTAFAS Y OTRAS DEFRAUDACIONES                      11755
# DELITOS CONTRA LA VIDA                               5932
# OTROS DELITOS CONTRA LA PROPIEDAD                    4154
# DELITOS INFORMATICOS                                 3352
# DELITOS CONTRA LA LIBERTAD                           3193
# OTROS DELITOS                                        2191
# DELITOS SEXUALES                                     1180
# DELITOS CONTRA LOS DEBERES DE LA FUNCION PUBLICA      922
# NO DELITO                                             622
# DELITOS CONTRA LA SEGURIDAD COMUN                     525
# DELITOS CONTRA LA ADMINISTRACION DE JUSTICIA          507
# INFRACCION A LA LEY DE PSICOTROPICOS                  473
# DELITOS CONTRA LA FAMILIA                             421
# INFRACCION A LA LEY DE BIENESTAR ANIMAL               201
# DELITOS AMBIENTALES                                   163
# ...

# %%
#limpieza de la parte de subdelitos

df2023 = df2023[df2023['SubDelito'].str.isupper()]

df2023['SubDelito'] = df2023['SubDelito'].str.replace('TIMOSSSSSSSSSSSSSSS', 'TIMOS')
df2023['SubDelito'] = df2023['SubDelito'].str.replace('HURTOSSSSSSSSSSSSSSSS', 'HURTOS')

df2023['SubDelito'] = df2023['SubDelito'].str.replace('EXTORSIONESSSSSSSSSSSSSSSSSS', 'EXTORSIONES')

df2023['SubDelito'] = df2023['SubDelito'].str.replace('HHHHHHHHHHHURTO', 'HURTO')


df2023['SubDelito'] = df2023['SubDelito'].str.replace('EXTORSIONESSSSSSSSSSSSSS', 'EXTORSIONES')



df2023['SubDelito'] = df2023['SubDelito'].str.replace('CÓDIGO DE MINERÍA 396', 'CÓDIGO DE MINERÍA')


df2023['SubDelito'] = df2023['SubDelito'].str.replace('HURTOS', 'HURTO')


df2023['SubDelito'] = df2023['SubDelito'].str.replace('AGRESIONNNNNNNNNNNNNNN', 'AGRESION')

df2023['SubDelito'] = df2023['SubDelito'].str.replace('OTRO O INDETERMINADO', 'OTRO INDETERMINADO')

df2023['SubDelito'] = df2023['SubDelito'].str.replace('TIMOSSSSSSSSSSSSS', 'TIMOS')


#limpieza de la parte de subdelitos 2022

df2022 = df2022[df2022['SubDelito'].str.isupper()]

df2022['SubDelito'] = df2022['SubDelito'].str.replace('ASALTO ASALTO ASALTO', 'ASALTO')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('ASALTOOOOOOOOOO', 'ASALTO')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('CORRUPCION, PROXENETISMO,RUFIANERIA66', 'CORRUPCION, PROXENETISMO,RUFIANERIA')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('DAÑOSSSSSSSSSSSSSSS', 'DAÑOS')


df2022['SubDelito'] = df2022['SubDelito'].str.replace('DELITOS CONTRA LA LIBERTAD DE DdETERMINACION', 'DELITOS CONTRA LA LIBERTAD DE DETERMINACION')


df2022['SubDelito'] = df2022['SubDelito'].str.replace('ESTAFA ESTAFA ESTAFA ESTAFA', 'ESTAFA')


df2022['SubDelito'] = df2022['SubDelito'].str.replace('HOMICIDIO O', 'HOMICIDIO')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('HURTO 506', 'HURTO')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('HURTO HURTO HURTO', 'HURTO')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('INJURIA, CALUMNIA, DIFAMACION PRAPRA', 'INJURIA, CALUMNIA, DIFAMACION')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('LESIONES ES', 'LESIONES')


df2022['SubDelito'] = df2022['SubDelito'].str.replace('OTRO O INDETERMINAD', 'OTRO INDETERMINADO')




df2022['SubDelito'] = df2022['SubDelito'].str.replace('ROBOOOOOOOOOOOOOOOOO', 'ROBO')

df2022['SubDelito'] = df2022['SubDelito'].str.replace('OTRO INDETERMINADOO', 'OTRO INDETERMINADO')




df2023.sort_values(by=['SubDelito']).to_excel('resultado.xlsx', sheet_name='Hoja1', index=False)


df2022.sort_values(by=['SubDelito']).to_excel('resultado1.xlsx', sheet_name='Hoja1', index=False)




print(df2023['SubDelito'])
# Out:
# 0        DELITOS CONTRA LA LIBERTAD DE DETERMINACION
# 1                                             ASALTO
# 2                                             ASALTO
# 3                                             ASALTO
# 4                                              HURTO
#                             ...
# 65721                DELITOS CONTRA LA SALUD PUBLICA
# 65722                                       AGRESION
# 65723                             OTRO INDETERMINADO
# 65724                             OTRO INDETERMINADO
# 65725                                    EXTORSIONES
# Name: SubDelito, Length: 65714, dtype: object

# %%
df2022.sort_values(by=['SubDelito']).to_excel('resultado2.xlsx', sheet_name='Hoja1', index=False)

# %%
df2023_Guanacaste= df2023[df2023['Provincia'].str.upper()== "GUANACASTE"]
df2022_Guanacaste= df2022[df2022['Provincia'].str.upper() =="GUANACASTE"]

print(df2023_Guanacaste)
print(df2022_Guanacaste)
# Out:
#                                                  Delito  \
# 0                            DELITOS CONTRA LA LIBERTAD
# 39                    OTROS DELITOS CONTRA LA PROPIEDAD
# 42                                        OTROS DELITOS
# 74                       ESTAFAS Y OTRAS DEFRAUDACIONES
# 89                          DELITOS CONTRA LA PROPIEDAD
# ...                                                 ...
# 65068  DELITOS CONTRA LOS DEBERES DE LA FUNCION PUBLICA
# 65069                    ESTAFAS Y OTRAS DEFRAUDACIONES
# 65082                 OTROS DELITOS CONTRA LA PROPIEDAD
# 65089                 OTROS DELITOS CONTRA LA PROPIEDAD
# 65106                       DELITOS CONTRA LA PROPIEDAD
#
#                                                SubDelito      Fecha  \
# 0            DELITOS CONTRA LA LIBERTAD DE DETERMINACION 2023-08-31
# 39                                           EXTORSIONES 2023-08-31
# 42                                  OTRO O INDETERMINADO 2023-08-31
# ...

# %% [markdown]
# ```
# ## 1.	Obtener los 5 delitos más comunes en su provincia.
# ```

# %%
# Calcular el recuento de frecuencia
frequencia_contar_df2023 = df2023_Guanacaste.value_counts()
frequencia_contar_df2022 = df2022_Guanacaste.value_counts()

# Obtener los 2 valores más frecuentes
mas_frecuente_2023 = frequencia_contar_df2023.nlargest(5).index
# Obtener los 2 valores más frecuentes
mas_frecuente_2022 = frequencia_contar_df2022.nlargest(5).index

print(mas_frecuente_2023)
print(mas_frecuente_2022)
# Out:
# MultiIndex([(   'DELITOS AMBIENTALES', 'LEY FORESTAL', '2023-02-28', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2023-05-19', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2023-05-31', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2023-05-29', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2023-05-29', ...)],
#            names=['Delito', 'SubDelito', 'Fecha', 'Hora', 'Victima', 'SubVictima', 'Edad', 'Genero', 'Nacionalidad', 'Provincia', 'Canton', 'Distrito'])
# MultiIndex([(   'DELITOS AMBIENTALES', 'LEY FORESTAL', '2022-09-22', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2022-09-20', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2022-10-02', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2022-09-30', ...),
#             ('DELITOS CONTRA LA VIDA',     'LESIONES', '2022-09-30', ...)],
# ...

# %% [markdown]
# # segun los subdelitos ¿Cuáles cantones y distritos tienen más homicidios (tome en cuenta homicidio y homicidio culposo) por conteo simple?

# %%
#Canton con mas homicidios

df2023_Guanacaste_homicidios= df2023_Guanacaste[df2023_Guanacaste['SubDelito'].str.upper().str.contains("HOMICIDIO") ]
df2022_Guanacaste_homicidios= df2022_Guanacaste[df2022_Guanacaste['SubDelito'].str.upper().str.contains("HOMICIDIO") ]

#print(df2023_Guanacaste_homicidios[["Provincia", "Canton", "Distrito"]])
#print(df2022_Guanacaste_homicidios[["Provincia", "Canton", "Distrito"]])
df2022_Guanacaste_homicidios_canton =  df2022_Guanacaste_homicidios[["Canton"]].groupby('Canton')

df2022_Guanacaste_homicidios_canton = df2022_Guanacaste_homicidios_canton.size().reset_index(name='Cantidad')
df2022_Guanacaste_homicidios_canton_ordenado = df2022_Guanacaste_homicidios_canton.sort_values(by='Cantidad', ascending=False)
print(df2022_Guanacaste_homicidios_canton_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False))

# Fixed: Use 'Cantidad' column for comparison instead of to_string
max_cantidad_2022 = df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].max()
canton_mas_homicidios_2022 = df2022_Guanacaste_homicidios_canton_ordenado[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'] == max_cantidad_2022]

#canton_mas_homicidios_2022= df2022_Guanacaste_homicidios_canton_ordenado[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].to_string == df2022_Guanacaste_homicidios_canton_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False)]

#canton_mas_homicidios_2022 = df2022_Guanacaste_homicidios_canton_ordenado.loc[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].idxmax(), ['Canton' , 'Cantidad']]

print("El canton con más homicidios 2022 es:", canton_mas_homicidios_2022)


df2023_Guanacaste_homicidios_canton =  df2023_Guanacaste_homicidios[["Canton"]].groupby('Canton')

df2023_Guanacaste_homicidios_canton = df2023_Guanacaste_homicidios_canton.size().reset_index(name='Cantidad')
df2023_Guanacaste_homicidios_canton_ordenado = df2023_Guanacaste_homicidios_canton.sort_values(by='Cantidad', ascending=False)
print(df2023_Guanacaste_homicidios_canton_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False))

# Fixed: Use 'Cantidad' column for comparison instead of to_string
max_cantidad_2023 = df2023_Guanacaste_homicidios_canton_ordenado['Cantidad'].max()
canton_mas_homicidios_2023 = df2023_Guanacaste_homicidios_canton_ordenado[df2023_Guanacaste_homicidios_canton_ordenado['Cantidad'] == max_cantidad_2023]

#canton_mas_homicidios_2022= df2022_Guanacaste_homicidios_canton_ordenado[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].to_string == df2022_Guanacaste_homicidios_canton_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False)]

#canton_mas_homicidios_2022 = df2022_Guanacaste_homicidios_canton_ordenado.loc[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].idxmax(), ['Canton' , 'Cantidad']]

print("El canton con más homicidios 2023 es:", canton_mas_homicidios_2023)
# Out:
#  Cantidad
#        30
# El canton con más homicidios 2022 es:     Canton  Cantidad
# 6  LIBERIA        30
#  Cantidad
#        24
# El canton con más homicidios 2023 es:        Canton  Cantidad
# 8  SANTA CRUZ        24

# %%
#Distrito con mas homicidios

#print(df2023_Guanacaste_homicidios[["Provincia", "Canton", "Distrito"]])
#print(df2022_Guanacaste_homicidios[["Provincia", "Canton", "Distrito"]])
df2022_Guanacaste_homicidios_Distrito =  df2022_Guanacaste_homicidios[["Distrito"]].groupby('Distrito')

df2022_Guanacaste_homicidios_Distrito = df2022_Guanacaste_homicidios_Distrito.size().reset_index(name='Cantidad')
df2022_Guanacaste_homicidios_Distrito_ordenado = df2022_Guanacaste_homicidios_Distrito.sort_values(by='Cantidad', ascending=False)
print(df2022_Guanacaste_homicidios_Distrito_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False))

# Fixed: Use 'Cantidad' column for comparison instead of to_string
Distrito_max_cantidad_2022 = df2022_Guanacaste_homicidios_Distrito_ordenado['Cantidad'].max()
Distrito_mas_homicidios_2022 = df2022_Guanacaste_homicidios_Distrito_ordenado[df2022_Guanacaste_homicidios_Distrito_ordenado['Cantidad'] == Distrito_max_cantidad_2022]

#canton_mas_homicidios_2022= df2022_Guanacaste_homicidios_canton_ordenado[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].to_string == df2022_Guanacaste_homicidios_canton_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False)]

#canton_mas_homicidios_2022 = df2022_Guanacaste_homicidios_canton_ordenado.loc[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].idxmax(), ['Canton' , 'Cantidad']]

print("El Distrito con más homicidios 2022 es:", Distrito_mas_homicidios_2022)

df2023_Guanacaste_homicidios_Distrito =  df2023_Guanacaste_homicidios[["Distrito"]].groupby('Distrito')

df2023_Guanacaste_homicidios_Distrito = df2023_Guanacaste_homicidios_Distrito.size().reset_index(name='Cantidad')
df2023_Guanacaste_homicidios_Distrito_ordenado = df2023_Guanacaste_homicidios_Distrito.sort_values(by='Cantidad', ascending=False)
print(df2023_Guanacaste_homicidios_Distrito_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False))

# Fixed: Use 'Cantidad' column for comparison instead of to_string
Distrito_max_cantidad_2023 = df2023_Guanacaste_homicidios_Distrito_ordenado['Cantidad'].max()
Distrito_mas_homicidios_2023 = df2023_Guanacaste_homicidios_Distrito_ordenado[df2023_Guanacaste_homicidios_Distrito_ordenado['Cantidad'] == Distrito_max_cantidad_2023]

#canton_mas_homicidios_2022= df2022_Guanacaste_homicidios_canton_ordenado[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].to_string == df2022_Guanacaste_homicidios_canton_ordenado[["Cantidad"]].nlargest(1, 'Cantidad').to_string(index=False)]

#canton_mas_homicidios_2022 = df2022_Guanacaste_homicidios_canton_ordenado.loc[df2022_Guanacaste_homicidios_canton_ordenado['Cantidad'].idxmax(), ['Canton' , 'Cantidad']]

print("El Distrito con más homicidios 2023 es:", Distrito_mas_homicidios_2023)
# Out:
#  Cantidad
#        29
# El Distrito con más homicidios 2022 es:    Distrito  Cantidad
# 15  LIBERIA        29
#  Cantidad
#        12
# El Distrito con más homicidios 2023 es:    Distrito  Cantidad
# 14  LIBERIA        12
# 18   NICOYA        12

# %% [markdown]
# #Pregunta numero 3

# %% [markdown]
# base de datos que cada grupo debe crear

# %%
# Input
Guanacaste_poblacion= pd.Series( [80130, 66268, 72366 , 23709 , 48227 , 31738 , 22211 , 21232 , 11874 , 26829 , 8224 ], ['Liberia' , 'Nicoya' , 'Santa Cruz' , 'Bagaces' , 'Carrillo' , 'Cañas' , 'Abangares' , 'Tilarán' , 'Nandayure' , 'La Cruz' , 'Hojancha'])
df_guanacaste_poblacion = Guanacaste_poblacion.reset_index()
df_guanacaste_poblacion.columns = ['Canton', 'poblacion']
# Output
df_guanacaste_poblacion['Canton'] = df_guanacaste_poblacion['Canton'].str.upper()


df_guanacaste_poblacion['Canton'] = df_guanacaste_poblacion['Canton'].str.replace('Ñ', 'N')

df_guanacaste_poblacion['Canton'] = df_guanacaste_poblacion['Canton'].str.replace('Á', 'A')

print (df_guanacaste_poblacion)
# Out:
#         Canton  poblacion
# 0      LIBERIA      80130
# 1       NICOYA      66268
# 2   SANTA CRUZ      72366
# 3      BAGACES      23709
# 4     CARRILLO      48227
# 5        CANAS      31738
# 6    ABANGARES      22211
# 7      TILARAN      21232
# 8    NANDAYURE      11874
# 9      LA CRUZ      26829
# 10    HOJANCHA       8224

# %%
#Guanacaste_homicidios_canton_total_2022  = df2022_Guanacaste_homicidios_canton.copy()
#Guanacaste_homicidios_canton_total_2022['Cantidad'] = Guanacaste_homicidios_canton_total_2022['Cantidad'] + df2023_Guanacaste_homicidios_canton['Cantidad']


# Combinar los DataFrames usando el campo común 'producto'
df_Guanacaste_homicidios_combinado_2022 = pd.merge(df2022_Guanacaste_homicidios_canton, df_guanacaste_poblacion, on='Canton', how='outer')

df_Guanacaste_homicidios_combinado_2022 = df_Guanacaste_homicidios_combinado_2022.fillna(0)
print(df_Guanacaste_homicidios_combinado_2022)

df_Guanacaste_homicidios_combinado_2023 = pd.merge(df2023_Guanacaste_homicidios_canton, df_guanacaste_poblacion, on='Canton', how='outer')
df_Guanacaste_homicidios_combinado_2023 = df_Guanacaste_homicidios_combinado_2023.fillna(0)

print(df_Guanacaste_homicidios_combinado_2023)


df_Guanacaste_homicidios_combinado_2022['tasa'] = (df_Guanacaste_homicidios_combinado_2022['Cantidad'] / df_Guanacaste_homicidios_combinado_2022['poblacion'] ) * 10000

df_Guanacaste_homicidios_combinado_2023['tasa'] = (df_Guanacaste_homicidios_combinado_2023['Cantidad'] / df_Guanacaste_homicidios_combinado_2023['poblacion'] ) * 10000
#print (df_Guanacaste_homicidios_combinado)

print(df_Guanacaste_homicidios_combinado_2022)
print(df_Guanacaste_homicidios_combinado_2023)


# Convert 'Cantidad' column to numeric in both DataFrames
df2022_Guanacaste_homicidios_canton['Cantidad'] = pd.to_numeric(df2022_Guanacaste_homicidios_canton['Cantidad'], errors='coerce')
df2023_Guanacaste_homicidios_canton['Cantidad'] = pd.to_numeric(df2023_Guanacaste_homicidios_canton['Cantidad'], errors='coerce')

# Now perform the addition




# + df2022_Guanacaste_homicidios[["Canton"]])
#df2022_Guanacaste_homicidios

#df_Guanacaste_homicidios_total= df2022_Guanacaste_homicidios.add(df2023_Guanacaste_homicidios, fill_value=0)
#df_Guanacaste_homicidios_total
#merged_inner = pd.merge(left=Guanacaste_poblacion,right=species_sub, left_on='species_id', right_on='species_id')
# En este caso, `species_id` es el único nombre de columna en los dos __DataFrames__, entonces si omitimos
# los argumentos `left_on` y `right_on` todavía obtendríamos el mismo resultado

# ¿Cuál es el tamaño de los datos en el resultado?
#merged_inner.shape
#merged_inner
# Out:
#          Canton  Cantidad  poblacion
# 0     ABANGARES       6.0    22211.0
# 1       BAGACES       7.0    23709.0
# 2         CANAS      10.0    31738.0
# 3      CARRILLO      15.0    48227.0
# 4   DESCONOCIDO       1.0        0.0
# 5      HOJANCHA       0.0     8224.0
# 6       LA CRUZ       8.0    26829.0
# 7       LIBERIA      30.0    80130.0
# 8     NANDAYURE       3.0    11874.0
# 9        NICOYA      22.0    66268.0
# 10   SANTA CRUZ      16.0    72366.0
# 11      TILARAN       6.0    21232.0
#          Canton  Cantidad  poblacion
# 0     ABANGARES       5.0    22211.0
# 1       BAGACES       3.0    23709.0
# 2         CANAS      10.0    31738.0
# 3      CARRILLO       8.0    48227.0
# 4   DESCONOCIDO       2.0        0.0
# 5      HOJANCHA       0.0     8224.0
# 6       LA CRUZ       2.0    26829.0
# 7       LIBERIA      17.0    80130.0
# 8     NANDAYURE       0.0    11874.0
# 9        NICOYA      17.0    66268.0
# 10   SANTA CRUZ      24.0    72366.0
# ...

# %%
import os

diractual = os.getcwd()
print(diractual)
# Out:
# /content

# %%
import os

# Especifica la ruta
ruta_archivo = r'"C:\\estadsticaspoliciales2023_modificado.xlsx'

# Verifica si la ruta existe
if os.path.exists(ruta_archivo):
    print("La ruta existe.")
else:
    print("La ruta no existe.")
# Out:
# La ruta no existe.
